# %% [markdown]
# NBA Games Analysis 🏀

# %% [markdown]
# Practice Exercise: Importing data & Exploring data (manipulation)
#
# Context:
# • The data is about NBA (National Basketball Association) games from 2004 season to Dec, 2020.
# • We'll be focusing on practicing importing data and data manipulation techniques learned in the course. But the dataset is also popular to be used for predicting NBA games winners.
# • We've made minor changes on the data to fit this exercise, such as changing the column names. Check out the original source if you are interested in using this data for other purposes (https://www.kaggle.com/nathanlauga/nba-games)
#
# Dataset Description:
# We'll work on two datasets (in two separate csv files):
# ⚫ games: each game from 2004 season to Dec 2020, including information about the two teams in each game, and some details like number of points, etc ⚫ teams: information about each team played in the games
# Assume we want to study the game level data, but with detailed information about each team. We'll need to combine these two datasets together.
#
#
# Objective:
# ⚫ Load/examine/subset/rename/change dtypes of columns for each individual dataset
# • Combine them into a single dataset, and export it
# • Explore the final dataset by subsetting or sorting
# 1. Import the libraries
# 2. Load the data in games.csv as a DataFrame called games
# Save the csv file under the same directory as the notebook if not typing the full path.
# Just
# into Data

# %% [markdown]
# 1. Import the Libraries

# %%
import pandas as pd

# %% [markdown]
# 2. Load the games.csv in the dataframe called games

# %%
games = pd.read_csv("./datasets/games.csv")

# %% [markdown]
# 3. Look at the first 5 rows of dataset

# %%
games.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      46.0    1610612759     117.0        0.478        0.815         0.321
# 1      40.0    1610612764     112.0        0.561        0.765         0.333
# 2      37.0    1610612749     106.0        0.470        0.682         0.433
# 3      49.0    1610612765      93.0        0.392        0.735         0.261
# 4      47.0    1610612741     110.0        0.500        0.773         0.292
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      23.0      44.0               1
# 1      20.0      37.0               1
# 2      20.0      46.0               1
# 3      15.0      46.0               1
# 4      20.0      47.0               0
#
# [5 rows x 21 columns]

# %%
games.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away',
#        'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
#        'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %% [markdown]
# 5. Reassign games as its subset of the columns 'GAME_DATE', 'GAME_STATUS_TEXT", "TEAM_ID_home', 'TEAM_ID_away', 'POINTS_home', 'POINTS_away', 'HOME_TEAM_WINS
# We'll only keep some columns about the games

# %%
games = games[['GAME_DATE_EST','GAME_STATUS_TEXT', 'TEAM_ID_home', 'TEAM_ID_away', 'PTS_home', 'PTS_away', 'HOME_TEAM_WINS']]

# %% [markdown]
# 6. Look at the new games DataFrame's first 5 rows, and info summary

# %%
print(games.head())
games.info()
# Out:
#   GAME_DATE_EST GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  PTS_home  \
# 0    2022-12-22            Final    1610612740    1610612759     126.0
# 1    2022-12-22            Final    1610612762    1610612764     120.0
# 2    2022-12-21            Final    1610612739    1610612749     114.0
# 3    2022-12-21            Final    1610612755    1610612765     113.0
# 4    2022-12-21            Final    1610612737    1610612741     108.0
#
#    PTS_away  HOME_TEAM_WINS
# 0     117.0               1
# 1     112.0               1
# 2     106.0               1
# 3      93.0               1
# 4     110.0               0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26651 entries, 0 to 26650
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     26651 non-null  object
#  1   GAME_STATUS_TEXT  26651 non-null  object
#  2   TEAM_ID_home      26651 non-null  int64
#  3   TEAM_ID_away      26651 non-null  int64
#  4   PTS_home          26552 non-null  float64
#  5   PTS_away          26552 non-null  float64
#  6   HOME_TEAM_WINS    26651 non-null  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# 7. Convert GAME_DATE to a datetime dtype

# %%
pd.to_datetime(games['GAME_DATE_EST'])
# Out:
# 0       2022-12-22
# 1       2022-12-22
# 2       2022-12-21
# 3       2022-12-21
# 4       2022-12-21
#            ...
# 26646   2014-10-06
# 26647   2014-10-06
# 26648   2014-10-06
# 26649   2014-10-05
# 26650   2014-10-04
# Name: GAME_DATE_EST, Length: 26651, dtype: datetime64[ns]

# %% [markdown]
# 8. Convert GAME_STATUS_TEXT to a string dtype

# %%
games['GAME_STATUS_TEXT'] = games['GAME_STATUS_TEXT'].astype(str)

# %% [markdown]
# 9. Look at the dataframe to verify the changes

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26651 entries, 0 to 26650
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GAME_DATE_EST     26651 non-null  object
#  1   GAME_STATUS_TEXT  26651 non-null  object
#  2   TEAM_ID_home      26651 non-null  int64
#  3   TEAM_ID_away      26651 non-null  int64
#  4   PTS_home          26552 non-null  float64
#  5   PTS_away          26552 non-null  float64
#  6   HOME_TEAM_WINS    26651 non-null  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# 10. Lood the teams.csv dataset into teams dataframe and see first 5 records

# %%
teams = pd.read_csv('./datasets/teams.csv')
teams.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# 0     Tony Ressler  Travis Schlenk   Lloyd Pierce      Erie Bayhawks
# 1    Wyc Grousbeck     Danny Ainge   Brad Stevens    Maine Red Claws
# 2       Tom Benson  Trajan Langdon   Alvin Gentry       No Affiliate
# 3  Jerry Reinsdorf      Gar Forman     Jim Boylen   Windy City Bulls
# 4       Mark Cuban   Donnie Nelson  Rick Carlisle      Texas Legends

# %% [markdown]
# 11. Reassign teams as a subset of its columns 'TEAM_ID', 'CITY', 'NICKNAME', and look at its first 5 rows and info summary
# We'll only keep some columns about the teams

# %%
teams = teams[['TEAM_ID','CITY','NICKNAME']]
teams.head()
# Out:
#       TEAM_ID         CITY   NICKNAME
# 0  1610612737      Atlanta      Hawks
# 1  1610612738       Boston    Celtics
# 2  1610612740  New Orleans   Pelicans
# 3  1610612741      Chicago      Bulls
# 4  1610612742       Dallas  Mavericks

# %% [markdown]
# 12. Convert both columns CITY and NICKNAME to a string dtype

# %%
teams['CITY'] = teams['CITY'].astype(str)
teams['NICKNAME'] = teams['NICKNAME'].astype(str)

# %% [markdown]
# 13. Verify the changes with the dtypes attribute

# %%
teams[['CITY','NICKNAME']].dtypes
# Out:
# CITY        object
# NICKNAME    object
# dtype: object

# %% [markdown]
# 14. Print out the first two rows of games and teams, how can we combine them?
#
# Hint:
#
# Within the games DataFrame, there are two columns TEAM_ID_home and TEAM_ID_away. This is because each game involves two teams playing against each other. The team that played in its own location, is called the 'home' team, the team that played outside its location, is called the 'away' team. Each game has one 'home' team and one 'away' team.
# While the teams DataFrame stores the information about each team, the identifier for each team is the column TEAM_ID.
# We can merge the two DataFrames based on:
# • TEAM_ID_home in games and TEAM_ID in teams: to get the team information for the 'home' team
# • TEAM_ID_away in games and TEAM_ID in teams: to get the team information for the 'away' team

# %%
games[:2]
# Out:
#   GAME_DATE_EST GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  PTS_home  \
# 0    2022-12-22            Final    1610612740    1610612759     126.0
# 1    2022-12-22            Final    1610612762    1610612764     120.0
#
#    PTS_away  HOME_TEAM_WINS
# 0     117.0               1
# 1     112.0               1

# %%
teams[:2]
# Out:
#       TEAM_ID     CITY NICKNAME
# 0  1610612737  Atlanta    Hawks
# 1  1610612738   Boston  Celtics

# %% [markdown]
# 15. Merge (inner) games and teams based on "TEAM_ID_home' and 'TEAM_ID', call the merged DataFrame games_with_home_team

# %%
games_with_home_team = pd.merge(games,teams,left_on='TEAM_ID_home',right_on='TEAM_ID',how='inner')

# %% [markdown]
# 16. Print out the first 5 rows of the new DataFrame
# Since we used the column TEAM_ID_home when merging, the two columns CITY and NICKNAME are storing the city and nickname of the 'home' team. So let's rename them.

# %%
games_with_home_team.head()
# Out:
#   GAME_DATE_EST GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  PTS_home  \
# 0    2022-12-22            Final    1610612740    1610612759     126.0
# 1    2022-12-19            Final    1610612740    1610612749     119.0
# 2    2022-12-11            Final    1610612740    1610612756     129.0
# 3    2022-12-09            Final    1610612740    1610612756     128.0
# 4    2022-12-07            Final    1610612740    1610612765     104.0
#
#    PTS_away  HOME_TEAM_WINS     TEAM_ID         CITY  NICKNAME
# 0     117.0               1  1610612740  New Orleans  Pelicans
# 1     128.0               0  1610612740  New Orleans  Pelicans
# 2     124.0               1  1610612740  New Orleans  Pelicans
# 3     117.0               1  1610612740  New Orleans  Pelicans
# 4      98.0               1  1610612740  New Orleans  Pelicans

# %% [markdown]
# 17. Rename the column CITY as 'city_home', NICKNAME as 'nickname_home"

# %%
games_with_home_team.rename(columns={'CITY':'city_home','NICKNAME':'nickname_home'},inplace=True)

# %% [markdown]
# 18. Merge (inner) games with_home_team and teams based on 'TEAM_ID_away' and 'TEAM_ID', call the merged DataFrame games_with_both_teams

# %%
games_with_both_teams = pd.merge(games_with_home_team, teams,left_on='TEAM_ID_away',right_on='TEAM_ID',how='inner')

# %% [markdown]
# 19. Print out the first 2 rows of the dataset
#
# Since we used the column TEAM_ID_away when merging, the two columns CITY and NICKNAME are storing the city and nickname of the 'away' team. So let's rename them.

# %%
games_with_both_teams[:2]
# Out:
#   GAME_DATE_EST GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  PTS_home  \
# 0    2022-12-22            Final    1610612740    1610612759     126.0
# 1    2022-04-13            Final    1610612740    1610612759     113.0
#
#    PTS_away  HOME_TEAM_WINS   TEAM_ID_x    city_home nickname_home  \
# 0     117.0               1  1610612740  New Orleans      Pelicans
# 1     103.0               1  1610612740  New Orleans      Pelicans
#
#     TEAM_ID_y         CITY NICKNAME
# 0  1610612759  San Antonio    Spurs
# 1  1610612759  San Antonio    Spurs

# %% [markdown]
# 20. Rename the column CITY as 'city_away', NICKNAME as 'nickname_away'

# %%
games_with_both_teams.rename(columns={'CITY':'city_away','NICKNAME':'nickname_away'},inplace=True)

# %% [markdown]
# 21. Print out the first 5 rows of the new DataFrame
# You probably have noticed that there are two columns called TEAM_ID_x and TEAM_ID_y. This is because we merged the DataFrame twice with the teams DataFrame. So the TEAM_ID column from teams is added twice to the merged DataFrame.

# %%
games_with_both_teams.head()
# Out:
#   GAME_DATE_EST GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  PTS_home  \
# 0    2022-12-22            Final    1610612740    1610612759     126.0
# 1    2022-04-13            Final    1610612740    1610612759     113.0
# 2    2022-03-26            Final    1610612740    1610612759     103.0
# 3    2022-02-12            Final    1610612740    1610612759     114.0
# 4    2021-04-24            Final    1610612740    1610612759     108.0
#
#    PTS_away  HOME_TEAM_WINS   TEAM_ID_x    city_home nickname_home  \
# 0     117.0               1  1610612740  New Orleans      Pelicans
# 1     103.0               1  1610612740  New Orleans      Pelicans
# 2     107.0               0  1610612740  New Orleans      Pelicans
# 3     124.0               0  1610612740  New Orleans      Pelicans
# 4     110.0               0  1610612740  New Orleans      Pelicans
#
#     TEAM_ID_y    city_away nickname_away
# 0  1610612759  San Antonio         Spurs
# 1  1610612759  San Antonio         Spurs
# 2  1610612759  San Antonio         Spurs
# 3  1610612759  San Antonio         Spurs
# 4  1610612759  San Antonio         Spurs

# %% [markdown]
# To avoide duplicate column names, pandas added the suffixes of 'x' and '_y' to distinguish them. But due to inner joins, TEAM_ID_x is the same as TEAM_ID_home, and TEAM_ID_y is the same as TEAM_ID_away.
# The team ID columns are not needed after the merge of the DataFrames.
# The below code is provided to drop the columns 'TEAM_ID_home', 'TEAM_ID_away', 'TEAM_ID_x", "TEAM_ID_y' from games_with_both_teams. We'll learn about this drop method in a later section

# %%
games_with_both_teams = games_with_both_teams.drop(columns=['TEAM_ID_home', 'TEAM_ID_away', 'TEAM_ID_x', 'TEAM_ID_y']) 
games_with_both_teams.head()
# Out:
#   GAME_DATE_EST GAME_STATUS_TEXT  PTS_home  PTS_away  HOME_TEAM_WINS  \
# 0    2022-12-22            Final     126.0     117.0               1
# 1    2022-04-13            Final     113.0     103.0               1
# 2    2022-03-26            Final     103.0     107.0               0
# 3    2022-02-12            Final     114.0     124.0               0
# 4    2021-04-24            Final     108.0     110.0               0
#
#      city_home nickname_home    city_away nickname_away
# 0  New Orleans      Pelicans  San Antonio         Spurs
# 1  New Orleans      Pelicans  San Antonio         Spurs
# 2  New Orleans      Pelicans  San Antonio         Spurs
# 3  New Orleans      Pelicans  San Antonio         Spurs
# 4  New Orleans      Pelicans  San Antonio         Spurs

# %% [markdown]
# 22. Make a copy of games_with_both_teams and assign it as games

# %%
games = games_with_both_teams.copy()

# %%
games.head()
# Out:
#   GAME_DATE_EST GAME_STATUS_TEXT  PTS_home  PTS_away  HOME_TEAM_WINS  \
# 0    2022-12-22            Final     126.0     117.0               1
# 1    2022-04-13            Final     113.0     103.0               1
# 2    2022-03-26            Final     103.0     107.0               0
# 3    2022-02-12            Final     114.0     124.0               0
# 4    2021-04-24            Final     108.0     110.0               0
#
#      city_home nickname_home    city_away nickname_away
# 0  New Orleans      Pelicans  San Antonio         Spurs
# 1  New Orleans      Pelicans  San Antonio         Spurs
# 2  New Orleans      Pelicans  San Antonio         Spurs
# 3  New Orleans      Pelicans  San Antonio         Spurs
# 4  New Orleans      Pelicans  San Antonio         Spurs

# %% [markdown]
# 23. Change the column names in games to all lowercase

# %%
games.columns = games.columns.str.lower()
# str.lower/upper/capitalize/title

# %% [markdown]
# 24. Print out the columns of games to verify the changes

# %%
games.columns
# Out:
# Index(['game_date_est', 'game_status_text', 'pts_home', 'pts_away',
#        'home_team_wins', 'city_home', 'nickname_home', 'city_away',
#        'nickname_away'],
#       dtype='object')

# %% [markdown]
# 25. Print out the columns of games_with_both_teams to verify that the original DataFrame wasn't impacted by the copy

# %%
games_with_both_teams.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_STATUS_TEXT', 'PTS_home', 'PTS_away',
#        'HOME_TEAM_WINS', 'city_home', 'nickname_home', 'city_away',
#        'nickname_away'],
#       dtype='object')

# %% [markdown]
# 26. Check the dimensionality of games

# %%
games.shape
# Out:
# (26651, 9)

# %% [markdown]
# 27. Export games as a csv file called 'games_transformed.csv', and open the csv file to look at it
# Feel free to test the difference of the csv files with or without the argument index=False

# %%
games.to_csv('games_transformed.csv',index=False) 
# index = false (do not include row number)
# index = True (include row number)

# %% [markdown]
# 28. Select all the columns of 'number' dtypes from games

# %%
num_cols = games.select_dtypes(include='number')
num_cols.head()
# Out:
#    pts_home  pts_away  home_team_wins
# 0     126.0     117.0               1
# 1     113.0     103.0               1
# 2     103.0     107.0               0
# 3     114.0     124.0               0
# 4     108.0     110.0               0

# %% [markdown]
# 29. Select all the columns NOT of 'number' dtypes from games

# %%
cat_cols = games.select_dtypes(exclude='number')
cat_cols.head()
# Out:
#   game_date_est game_status_text    city_home nickname_home    city_away  \
# 0    2022-12-22            Final  New Orleans      Pelicans  San Antonio
# 1    2022-04-13            Final  New Orleans      Pelicans  San Antonio
# 2    2022-03-26            Final  New Orleans      Pelicans  San Antonio
# 3    2022-02-12            Final  New Orleans      Pelicans  San Antonio
# 4    2021-04-24            Final  New Orleans      Pelicans  San Antonio
#
#   nickname_away
# 0         Spurs
# 1         Spurs
# 2         Spurs
# 3         Spurs
# 4         Spurs

# %% [markdown]
# 30. Print out the first 5 rows of games as a reference.

# %%
games.rename(columns={'game_date_est': 'game_date'}, inplace=True)

games.head()
# Out:
#     game_date game_status_text  pts_home  pts_away  home_team_wins  \
# 0  2022-12-22            Final     126.0     117.0               1
# 1  2022-04-13            Final     113.0     103.0               1
# 2  2022-03-26            Final     103.0     107.0               0
# 3  2022-02-12            Final     114.0     124.0               0
# 4  2021-04-24            Final     108.0     110.0               0
#
#      city_home nickname_home    city_away nickname_away
# 0  New Orleans      Pelicans  San Antonio         Spurs
# 1  New Orleans      Pelicans  San Antonio         Spurs
# 2  New Orleans      Pelicans  San Antonio         Spurs
# 3  New Orleans      Pelicans  San Antonio         Spurs
# 4  New Orleans      Pelicans  San Antonio         Spurs

# %% [markdown]
# 31. Select the row with label 0

# %%
games.loc[0]
# Out:
# game_date            2022-12-22
# game_status_text          Final
# pts_home                  126.0
# pts_away                  117.0
# home_team_wins                1
# city_home           New Orleans
# nickname_home          Pelicans
# city_away           San Antonio
# nickname_away             Spurs
# Name: 0, dtype: object

# %% [markdown]
# 32. Select the row with integer position 0

# %%
games.iloc[0]
# Out:
# game_date            2022-12-22
# game_status_text          Final
# pts_home                  126.0
# pts_away                  117.0
# home_team_wins                1
# city_home           New Orleans
# nickname_home          Pelicans
# city_away           San Antonio
# nickname_away             Spurs
# Name: 0, dtype: object

# %% [markdown]
# 33. Set the column game_date as the index of DataFrame games

# %%
games.set_index('game_date',inplace=True)

# %% [markdown]
# 34. Print out the index of games to verify the changes

# %%
games.index
# Out:
# Index(['2022-12-22', '2022-04-13', '2022-03-26', '2022-02-12', '2021-04-24',
#        '2020-12-27', '2020-12-27', '2020-08-09', '2020-01-22', '2014-02-03',
#        ...
#        '2018-04-07', '2017-11-25', '2017-04-08', '2016-11-07', '2016-03-14',
#        '2015-10-27', '2015-04-20', '2015-04-18', '2015-03-20', '2014-12-04'],
#       dtype='object', name='game_date', length=26651)

# %% [markdown]
# 35. Select the rows with label '2020-12-18'

# %%
games.loc['2020-12-18']
# Out:
#            game_status_text  pts_home  pts_away  home_team_wins  \
# game_date
# 2020-12-18            Final     127.0     113.0               1
# 2020-12-18            Final     103.0     105.0               0
# 2020-12-18            Final     129.0      96.0               1
# 2020-12-18            Final     113.0     114.0               0
# 2020-12-18            Final     105.0     117.0               0
# 2020-12-18            Final     119.0      83.0               1
# 2020-12-18            Final      89.0     113.0               0
# 2020-12-18            Final     107.0     113.0               0
#
#                 city_home nickname_home     city_away  nickname_away
# game_date
# 2020-12-18    New Orleans      Pelicans     Milwaukee          Bucks
# 2020-12-18  Oklahoma City       Thunder       Chicago          Bulls
# 2020-12-18         Denver       Nuggets      Portland  Trail Blazers
# 2020-12-18        Phoenix          Suns   Los Angeles         Lakers
# 2020-12-18        Toronto       Raptors         Miami           Heat
# 2020-12-18       New York        Knicks     Cleveland      Cavaliers
# 2020-12-18         Boston       Celtics      Brooklyn           Nets
# 2020-12-18        Indiana        Pacers  Philadelphia          76ers

# %% [markdown]
# 36. Select the rows with labels from '2020-12-18' to '2020-12-19'

# %%
# Ensure that 'game_date' is in datetime format
games.index = pd.to_datetime(games.index)

# Select the rows with labels from '2020-12-18' to '2020-12-19'
games.loc['2020-12-18':'2020-12-19']
# Out:
#            game_status_text  pts_home  pts_away  home_team_wins  \
# game_date
# 2020-12-18            Final     127.0     113.0               1
# 2020-12-19            Final      99.0      96.0               1
# 2020-12-18            Final     103.0     105.0               0
# 2020-12-18            Final     129.0      96.0               1
# 2020-12-19            Final     116.0     117.0               0
# 2020-12-18            Final     113.0     114.0               0
# 2020-12-19            Final     120.0     117.0               1
# 2020-12-18            Final     105.0     117.0               0
# 2020-12-18            Final     119.0      83.0               1
# 2020-12-18            Final      89.0     113.0               0
# 2020-12-18            Final     107.0     113.0               0
#
#                 city_home nickname_home     city_away  nickname_away
# game_date
# 2020-12-18    New Orleans      Pelicans     Milwaukee          Bucks
# 2020-12-19     Washington       Wizards       Detroit        Pistons
# 2020-12-18  Oklahoma City       Thunder       Chicago          Bulls
# 2020-12-18         Denver       Nuggets      Portland  Trail Blazers
# 2020-12-19        Memphis     Grizzlies       Atlanta          Hawks
# 2020-12-18        Phoenix          Suns   Los Angeles         Lakers
# 2020-12-19        Orlando         Magic     Charlotte        Hornets
# 2020-12-18        Toronto       Raptors         Miami           Heat
# 2020-12-18       New York        Knicks     Cleveland      Cavaliers
# 2020-12-18         Boston       Celtics      Brooklyn           Nets
# 2020-12-18        Indiana        Pacers  Philadelphia          76ers

# %% [markdown]
# 37. Select the rows with labels of '2020-12-18' and '2019-12-18'

# %%
games.loc[['2019-12-18','2020-12-18']]
# Out:
#            game_status_text  pts_home  pts_away  home_team_wins  \
# game_date
# 2019-12-18            Final      99.0     112.0               0
# 2019-12-18            Final     122.0     112.0               1
# 2019-12-18            Final     103.0     109.0               0
# 2019-12-18            Final     109.0     110.0               0
# 2019-12-18            Final     126.0     122.0               1
# 2019-12-18            Final     100.0      98.0               1
# 2019-12-18            Final     113.0     104.0               1
# 2019-12-18            Final     104.0     108.0               0
# 2019-12-18            Final      99.0     107.0               0
# 2020-12-18            Final     127.0     113.0               1
# 2020-12-18            Final     103.0     105.0               0
# 2020-12-18            Final     129.0      96.0               1
# 2020-12-18            Final     113.0     114.0               0
# 2020-12-18            Final     105.0     117.0               0
# 2020-12-18            Final     119.0      83.0               1
# 2020-12-18            Final      89.0     113.0               0
# 2020-12-18            Final     107.0     113.0               0
#
#                 city_home  nickname_home     city_away  nickname_away
# game_date
# 2019-12-18        Detroit        Pistons       Toronto        Raptors
# 2019-12-18       Portland  Trail Blazers  Golden State       Warriors
# 2019-12-18         Dallas      Mavericks        Boston        Celtics
# 2019-12-18     Washington        Wizards       Chicago          Bulls
# 2019-12-18  Oklahoma City        Thunder       Memphis      Grizzlies
# 2019-12-18      Cleveland      Cavaliers     Charlotte        Hornets
# 2019-12-18         Denver        Nuggets       Orlando          Magic
# 2019-12-18   Philadelphia          76ers         Miami           Heat
# 2019-12-18      Minnesota   Timberwolves   New Orleans       Pelicans
# 2020-12-18    New Orleans       Pelicans     Milwaukee          Bucks
# 2020-12-18  Oklahoma City        Thunder       Chicago          Bulls
# 2020-12-18         Denver        Nuggets      Portland  Trail Blazers
# 2020-12-18        Phoenix           Suns   Los Angeles         Lakers
# 2020-12-18        Toronto        Raptors         Miami           Heat
# 2020-12-18       New York         Knicks     Cleveland      Cavaliers
# 2020-12-18         Boston        Celtics      Brooklyn           Nets
# 2020-12-18        Indiana         Pacers  Philadelphia          76ers

# %% [markdown]
# 38. Select the rows with points_home greater than 150

# %%
games[games['pts_home']>150].sort_values(by='pts_home',ascending=False)
# Out:
#            game_status_text  pts_home  pts_away  home_team_wins  \
# game_date
# 2008-03-16            Final     168.0     116.0               1
# 2019-03-01            Final     161.0     168.0               0
# 2019-10-30            Final     158.0     159.0               0
# 2019-11-30            Final     158.0     111.0               1
# 2006-12-07            Final     157.0     161.0               0
# 2019-01-10            Final     154.0     147.0               1
# 2020-08-25            Final     154.0     111.0               1
# 2021-05-03            Final     154.0     141.0               1
# 2022-02-25            Final     153.0     157.0               0
# 2022-11-15            Final     153.0     121.0               1
# 2021-12-02            Final     152.0      79.0               1
# 2010-03-16            Final     152.0     114.0               1
# 2020-01-26            Final     152.0     133.0               1
# 2006-12-27            Final     151.0     145.0               1
# 2008-04-06            Final     151.0     147.0               1
# 2020-01-28            Final     151.0     131.0               1
#
#                 city_home nickname_home      city_away nickname_away
# game_date
# 2008-03-16         Denver       Nuggets  Oklahoma City       Thunder
# 2019-03-01        Atlanta         Hawks        Chicago         Bulls
# 2019-10-30     Washington       Wizards        Houston       Rockets
# 2019-11-30        Houston       Rockets        Atlanta         Hawks
# 2006-12-07       Brooklyn          Nets        Phoenix          Suns
# 2019-01-10    San Antonio         Spurs  Oklahoma City       Thunder
# 2020-08-25    Los Angeles      Clippers         Dallas     Mavericks
# 2021-05-03     Washington       Wizards        Indiana        Pacers
# 2022-02-25     Washington       Wizards    San Antonio         Spurs
# 2022-11-15     Sacramento         Kings       Brooklyn          Nets
# 2021-12-02        Memphis     Grizzlies  Oklahoma City       Thunder
# 2010-03-16        Phoenix          Suns      Minnesota  Timberwolves
# 2020-01-26        Atlanta         Hawks     Washington       Wizards
# 2006-12-27       New York        Knicks        Detroit       Pistons
# 2008-04-06  Oklahoma City       Thunder         Denver       Nuggets
# 2020-01-28      Milwaukee         Bucks     Washington       Wizards

# %% [markdown]
# 39. Select the rows with points_home greater than 150, and home_team_wins not being 1

# %%
games[(games['pts_home'] > 150) & (games['home_team_wins'] <= 0)]
# Out:
#            game_status_text  pts_home  pts_away  home_team_wins   city_home  \
# game_date
# 2022-02-25            Final     153.0     157.0               0  Washington
# 2006-12-07            Final     157.0     161.0               0    Brooklyn
# 2019-03-01            Final     161.0     168.0               0     Atlanta
# 2019-10-30            Final     158.0     159.0               0  Washington
#
#            nickname_home    city_away nickname_away
# game_date
# 2022-02-25       Wizards  San Antonio         Spurs
# 2006-12-07          Nets      Phoenix          Suns
# 2019-03-01         Hawks      Chicago         Bulls
# 2019-10-30       Wizards      Houston       Rockets

# %% [markdown]
# 40. Select the rows with points home greater than 150, and home_team_wins not being 1, as well as the columns home_team_wins and points_home

# %%
games[(games['pts_home'] > 150) & (games['home_team_wins'] != 1)][['home_team_wins', 'pts_home']]
# Out:
#             home_team_wins  pts_home
# game_date
# 2022-02-25               0     153.0
# 2006-12-07               0     157.0
# 2019-03-01               0     161.0
# 2019-10-30               0     158.0

# %% [markdown]
# 41. Reset the index of games back to default and verify the changes

# %%
games.reset_index(drop=True, inplace=True)

# %% [markdown]
# 42. Add a new column called points_total, as the sum of columns points_home and points_away

# %%
games['points_total'] = games['pts_home']+games['pts_away']

# %% [markdown]
# 43. Verify the changes by printing out the three columns points_home, points_away, points_total

# %%
games[['pts_home', 'pts_away', 'points_total']]
# Out:
#        pts_home  pts_away  points_total
# 0         126.0     117.0         243.0
# 1         113.0     103.0         216.0
# 2         103.0     107.0         210.0
# 3         114.0     124.0         238.0
# 4         108.0     110.0         218.0
# ...         ...       ...           ...
# 26646     111.0      95.0         206.0
# 26647      97.0      87.0         184.0
# 26648     106.0      99.0         205.0
# 26649     112.0      96.0         208.0
# 26650     112.0      85.0         197.0
#
# [26651 rows x 3 columns]

# %% [markdown]
# 44. Print out the 3 rows with the largest points_total using the largest method

# %%
games.nlargest(n=3,columns='points_total')
# Out:
#       game_status_text  pts_home  pts_away  home_team_wins   city_home  \
# 8301             Final     161.0     168.0               0     Atlanta
# 1994             Final     157.0     161.0               0    Brooklyn
# 10704            Final     158.0     159.0               0  Washington
#
#       nickname_home city_away nickname_away  points_total
# 8301          Hawks   Chicago         Bulls         329.0
# 1994           Nets   Phoenix          Suns         318.0
# 10704       Wizards   Houston       Rockets         317.0

# %% [markdown]
# 45. Sort the DataFrame games by its points_total column in ascending order Don't forget to reassign the sorted result back to games

# %%
sorted_games = games.sort_values(by='points_total',ascending=True)

# %% [markdown]
# 46. Print out the last 3 rows of the sorted DataFrame
# Verify that it's the same three rows as the previous example (nlargest)

# %%
sorted_games.tail(3)

# note we have nan values in points table so we can't get it we need to remove nan values
# Out:
#       game_status_text  pts_home  pts_away  home_team_wins    city_home  \
# 26366            Final       NaN       NaN               0  San Antonio
# 26479            Final       NaN       NaN               0       Dallas
# 26548            Final       NaN       NaN               0      Orlando
#
#       nickname_home    city_away nickname_away  points_total
# 26366         Spurs  New Orleans      Pelicans           NaN
# 26479     Mavericks  New Orleans      Pelicans           NaN
# 26548         Magic  New Orleans      Pelicans           NaN

# %% [markdown]
# 47. Given that the DataFrame is sorted by points_total, select the row with the smallest points_total using iloc

# %%
sorted_games.iloc[0]
# Out:
# game_status_text       Final
# pts_home                36.0
# pts_away                33.0
# home_team_wins             1
# city_home             Boston
# nickname_home        Celtics
# city_away           Brooklyn
# nickname_away           Nets
# points_total            69.0
# Name: 23366, dtype: object

# %% [markdown]
# 48. Select the rows with the second, and third smallest points_total using iloc

# %%
sorted_games.iloc[[2,3]]
# Out:
#       game_status_text  pts_home  pts_away  home_team_wins city_home  \
# 10973            Final      64.0      60.0               1  Brooklyn
# 12987            Final      64.0      62.0               1   Detroit
#
#       nickname_home city_away  nickname_away  points_total
# 10973          Nets  Portland  Trail Blazers         124.0
# 12987       Pistons      Utah           Jazz         126.0

# %% [markdown]
# 49. Select a subset including the first 4 rows, and the first 5 columns using iloc

# %%
sorted_games.iloc[:4,:5]
# Out:
#       game_status_text  pts_home  pts_away  home_team_wins city_home
# 23366            Final      36.0      33.0               1    Boston
# 8684             Final      62.0      58.0               1   Indiana
# 10973            Final      64.0      60.0               1  Brooklyn
# 12987            Final      64.0      62.0               1   Detroit
